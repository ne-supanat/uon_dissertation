# %% [markdown]
# # Template

# %%
import pandas as pd
import plotly.express as px
import os

df = pd.read_csv('./NetLogo Model/outputs.csv')

# Create line chart using plotly
fig = px.line(df, title='Mode of Transport', labels={'value':'Number of People', 'index':'Time Step', 'variable':'Mode'})

# Update layout for better readability
fig.update_layout(title_x=0.5,  # Center the title
                  xaxis_title='Time Step',
                  yaxis_title='Number of People',
                  legend_title='Mode of Transport')

# Save visualisation image in folder visualisations
os.makedirs("results_2/visualisations", exist_ok=True)
fig.write_image("results_2/visualisations/transport_modes.png")

#Optionally display the figure
#fig.show()

# %% [markdown]
# ## Scenario 25%

# %%
import pandas as pd
import plotly.express as px
import os

df = pd.read_csv('./NetLogo Model/outputs_25.csv')

# Create line chart using plotly
fig = px.area(df, title='Mode of Transport (25% environment concious commuter)', labels={'value':'Number of People', 'index':'Time Step', 'variable':'Mode'})

# Update layout for better readability
fig.update_layout(title_x=0.5,  # Center the title
                  xaxis_title='Time Step',
                  yaxis_title='Number of People',
                  legend_title='Mode of Transport')

# Save visualisation image in folder visualisations
os.makedirs("results_2/visualisations", exist_ok=True)
fig.write_image("results_2/visualisations/v25_fill.png")

#Optionally display the figure
fig.show()

# %% [markdown]
# ## Scenario 75%

# %%
import pandas as pd
import plotly.express as px
import os

df = pd.read_csv('./NetLogo Model/outputs_75.csv')

# Create line chart using plotly
fig = px.area(df, title='Mode of Transport (75% environment concious commuter)', labels={'value':'Number of People', 'index':'Time Step', 'variable':'Mode'})

# Update layout for better readability
fig.update_layout(title_x=0.5,  # Center the title
                  xaxis_title='Time Step',
                  yaxis_title='Number of People',
                  legend_title='Mode of Transport')

# Save visualisation image in folder visualisations
os.makedirs("results_2/visualisations", exist_ok=True)
fig.write_image("results_2/visualisations/v75_fill.png")

#Optionally display the figure
fig.show()

# %%
import pandas as pd
import plotly.express as px
import os

df = pd.read_csv('./NetLogo Model/outputs.csv')

# Create the line chart using Plotly
fig = px.line(df, 
              title='Transport Usage Over Time (Traffic Is Cogestion at 500 ticks)', 
              labels={'value': 'Number of Agents', 'variable': 'Transport Type'})

# Update layout for better readability
fig.update_layout(xaxis_title='Tick', yaxis_title='Number of Agents')

# Save visualisation image in folder visualisations
os.makedirs("travel/visualisations", exist_ok=True)
fig.write_image("travel/visualisations/transport_usage.png")

#Optionally show the figure
fig.show()
